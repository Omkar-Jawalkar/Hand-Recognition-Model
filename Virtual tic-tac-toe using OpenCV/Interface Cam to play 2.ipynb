# %%
import cv2
import os
import HandTrackingMod as htm
import time 
import autopy
import pynput
import numpy as np
from datetime import datetime

# %%
cap = cv2.VideoCapture(0)
w,h = autopy.screen.size()
cap.set(3, 1920)
cap.set(4, 1080)
wCam = 1920
hCam = 1080
w1 = w // 2
print(w,h)
duration = 5
# Out:
# 1536.0 864.0

# %%
def inputNames():
    A = "Player 1: "
    B = "Player 2: "
    p1 = str(input("Player 1 : "))
    p2 = str(input("Player 2 : "))  
    A = A+p1
    B = B+p2
    return A,B

# %%
lcordx1, lcordy2 = 650,0
lcordx2, lcordy2 = 650, 721
frameR = 100
t = 15



detector = htm.handDetector()
A, B= inputNames()
m1,m2 = autopy.mouse.location()
while True:
    success, img = cap.read()
    img = cv2.flip(img, 1)
    img = detector.findHands(img)
    lmList, bbox = detector.findPosition(img, handNo =0)
    
    if len(lmList) != 0:
        x1,y1 = lmList[8][1:]
        x2,y2 = lmList[12][1:]
        s1 = x1+y1
        s2 = x2+y2
        fingers = detector.fingersUp()
         #Check selection mode and action mode
        if fingers[1] ==1 and fingers[2] == 1:
            cv2.line(img,(x1,y1),( x2,y2),(255,255,255),4)
            m1,m2 = autopy.mouse.location()
#             print(s2-s1)
            if (s2-s1)>80:
                cv2.circle(img, (x1, y1), 5, (0, 0 ,0), cv2.FILLED)               
                cv2.circle(img, (x2, y2), 5, (0, 0 ,0), cv2.FILLED)            
                autopy.mouse.click()
        elif fingers[1] == 1:
            x3 = np.interp(x1, (frameR,wCam-frameR), (0,w))
            y3 = np.interp(y1, (frameR,hCam-frameR), (0,h))
            autopy.mouse.move(w - x3 ,y3)
#             cv2.circle(img, (x1, y1), 19, (0, 0 ,0), cv2.FILLED)            
    
            print(m1,m2)
#             if m1
        
        
        
        
    cv2.line(img,(650,0),( 650, 721),(0, 0, 0),9)
    cv2.rectangle(img, (320,0 + 40), (600, 0 + 220), (255,0,0), 5)
    cv2.rectangle(img, (960,0 + 40), (1215, 0 + 220), (255,0,0), 5)
    cv2.putText(img,str(A),(30,60), cv2.FONT_HERSHEY_PLAIN, 1.8,(255,255,255),2,cv2.LINE_AA)
    cv2.putText(img,str(B),(680,60), cv2.FONT_HERSHEY_PLAIN, 1.8,(255,255,255),2,cv2.LINE_AA)
    cv2.putText(img, str(t), (70 ,655), cv2.FONT_HERSHEY_PLAIN, 
                2, (0,255,0), 3)
    
   
    

        
    
    
    
    
    cv2.imshow("Play XO game", img)
    
    
    cv2.waitKey(1)
# Out:
# Player 1 : om
# Player 2 : o
# 439.2 476.8
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 738.4 366.4
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# 1037.6 257.6
# ...

# %%
def countDownTimer(t):
    
    return res

# %%
b = countDownTimer(15)
print(b)

# %%
inputNames()
# Out:
# Player 1: om
# Player 2: as
# Player 1: om Player 2: as
# ('Player 1: om', 'Player 2: as')

# %% [markdown]
# # TKinter for Counter
